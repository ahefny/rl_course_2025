# %%
# Setup

from IPython.display import clear_output

# !git clone -q https://github.com/ahefny/rl_course_2025.git
# %cd rl_course_2025
# !pip install -q -r deep_rl/requirements_colab.txt

clear_output()

# %%
# %load_ext tensorboard
# %tensorboard --logdir runs

# %%
# !python deep_rl/ppo.py
